# %% [markdown]
# ### Exploratory data analysis

# %%
import plotnine as p9
import pandas as pd

# %%
people = pd.read_csv('data/olyathswim.csv')
people = people[['Sex', 'Weight', 'Height']]
# people = pd.read_csv('data/undata_country_profile_variables.csv')
people = people.dropna()
people.head()
# Out:
#    Sex  Weight  Height
# 8    M   130.0   189.0
# 9    M    70.0   174.0
# 11   M    76.0   187.0
# 12   M    78.0   194.0
# 13   M    78.0   194.0

# %% [markdown]
# ### Scatter plot

# %%
# Create the scatter plot
print(p9.ggplot(people)+ p9.aes(x='Height', y="Weight", color='Sex')+ p9.geom_point())
# Out:
# <ggplot: (-9223371903346850251)>

# %% [markdown]
# ### Boxplots
# -  a great way to get an overview of a distribution.
# - We'll make two boxplots: one for Weight and one for Height.

# %%
# Create boxplot of Weight
print(p9.ggplot(people)+ p9.aes(x='Sex', y='Weight', fill='Sex')+ p9.geom_boxplot())
# Out:
# <ggplot: (-9223371903346853849)>

# %%
# Create boxplot of Height
print(p9.ggplot(people)+ p9.aes(x='Sex', y='Height', fill='Sex')+ p9.geom_boxplot())
# Out:
# <ggplot: (133507502400)>

# %%
# Create density plot of Height
print(p9.ggplot(people)+ p9.aes(x='Height', fill="Sex")+ p9.geom_density(alpha=0.5))
